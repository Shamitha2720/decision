# %% [markdown]
# ## Assignment 1
# ### Name: Ambati shamitha
# ### Roll Number: 21CS30004

# %%
# import all the necessary libraries here
# import all the necessary libraries here
import pandas as pd
from sklearn import model_selection
import math

# %%
df = pd.read_csv('../../dataset/decision-tree.csv')
print(df.shape)
# Out:
# (768, 9)

# %%
def unique_vals(rows, col):
    """Find the unique values for a column in a dataset."""
    return set([row[col] for row in rows])

#######
# Demo:
# unique_vals(training_data, 0)
# unique_vals(training_data, 1)
#######


def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

#######
# Demo:
# class_counts(training_data)
#######




def max_label(dict):
    max_count = 0
    label = ""

    for key, value in dict.items():
        if dict[key] > max_count:
            max_count = dict[key]
            label = key

    return label




def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

#######
# Demo:
# is_numeric(7)
# is_numeric("Red")
#######


class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self, column, value, header):
        self.column = column
        self.value = value
        self.header = header

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            self.header[self.column], condition, str(self.value))


def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows


def gini(rows):
    """Calculate the Gini Impurity for a list of rows.

    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

## TODO: Step 3
def entropy(rows):

    # compute the entropy.
    entries = class_counts(rows)
    avg_entropy = 0
    size = float(len(rows))
    for label in entries:
        prob = entries[label] / size
        avg_entropy = avg_entropy + (prob * math.log(prob, 2))
    return -1*avg_entropy


def info_gain(left, right, current_uncertainty):
    """Information Gain.

    The uncertainty of the starting node, minus the weighted impurity of
    two child nodes.
    """
    p = float(len(left)) / (len(left) + len(right))

    ## TODO: Step 3, Use Entropy in place of Gini
    return current_uncertainty - p * entropy(left) - (1 - p) * entropy(right)

def find_best_split(rows, header):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = entropy(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val, header)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

## TODO: Step 2
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows, id, depth):
        self.predictions = class_counts(rows)
        self.predicted_label = max_label(self.predictions)
        self.id = id
        self.depth = depth

## TODO: Step 1
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch,
                 depth,
                 id,
                 rows):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch
        self.depth = depth
        self.id = id
        self.rows = rows


## TODO: Step 3
def build_tree(rows, header, depth=0, id=0):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """
    # depth = 0
    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.

    if(depth>10):
        return Leaf(rows,id,depth)
    gain, question = find_best_split(rows, header)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows, id, depth)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    # nodeLst.append(id)
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows, header, depth + 1, 2 * id + 2)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows, header, depth + 1, 2 * id + 1)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # depending on on the answer.
    return Decision_Node(question, true_branch, false_branch, depth, id, rows)

## TODO: Step 8 - already done for you
def prune_tree(node, prunedList):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node
    # If we reach a pruned node, make that node a leaf node and return. Since it becomes a leaf node, the nodes
    # below it are automatically not considered
    if int(node.id) in prunedList:
        return Leaf(node.rows, node.id, node.depth)

    # Call this function recursively on the true branch
    node.true_branch = prune_tree(node.true_branch, prunedList)

    # Call this function recursively on the false branch
    node.false_branch = prune_tree(node.false_branch, prunedList)

    return node

## TODO: Step 6
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predicted_label

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

## TODO: Step 4
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print(spacing + "Leaf id: " + str(node.id) + " Predictions: " + str(node.predictions) + " Label Class: " + str(node.predicted_label))
        return

    # Print the question at this node
    print(spacing + str(node.question) + " id: " + str(node.id) + " depth: " + str(node.depth))

    # Call this function recursively on the true branch
    print(spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print(spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")


def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

## TODO: Step 5
def getLeafNodes(node, leafNodes =[]):

    # Base case
    if isinstance(node, Leaf):
        leafNodes.append(node)
        return

    # Recursive right call for true values
    getLeafNodes(node.true_branch, leafNodes)

    # Recursive left call for false values
    getLeafNodes(node.false_branch, leafNodes)

    return leafNodes


def getInnerNodes(node, innerNodes =[]):

    # Base case
    if isinstance(node, Leaf):
        return

    innerNodes.append(node)

    # Recursive right call for true values
    getInnerNodes(node.true_branch, innerNodes)

    # Recursive left call for false values
    getInnerNodes(node.false_branch, innerNodes)

    return innerNodes

## TODO: Step 6
def computeAccuracy(rows, node):

    count = len(rows)
    if count == 0:
        return 0

    accuracy = 0
    for row in rows:
        # last entry of the column is the actual label
        if row[-1] == classify(row, node):
            accuracy += 1
    return round(accuracy/count, 2)

# default data set

header = list(df.columns)

# overwrite your data set here
# header = ['SepalL', 'SepalW', 'PetalL', 'PetalW', 'Class']
# df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None, names=['SepalL','SepalW','PetalL','PetalW','Class'])
# data-set link: https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer/
# df = pd.read_csv('data_set/breast-cancer.csv')


lst = df.values.tolist()

# splitting the data set into train and test
trainDF, testDF = model_selection.train_test_split(lst, test_size=0.2)

# building the tree
t = build_tree(trainDF, header)

# get leaf and inner nodes
print("\nLeaf nodes ****************")
leaves = getLeafNodes(t)
for leaf in leaves:
    print("id = " + str(leaf.id) + " depth =" + str(leaf.depth))

print("\nNon-leaf nodes ****************")
innerNodes = getInnerNodes(t)

for inner in innerNodes:
    print("id = " + str(inner.id) + " depth =" + str(inner.depth))

# print tree
maxAccuracy = computeAccuracy(testDF, t)
print("\nTree before pruning with accuracy: " + str(maxAccuracy*100) + "\n")
print_tree(t)

# TODO: You have to decide on a pruning strategy
# Pruning strategy
nodeIdToPrune = -1
import copy
t1=copy.deepcopy(t)
for node in innerNodes:
    if node.id != 0:
        prune_tree(t, [node.id])
        currentAccuracy = computeAccuracy(testDF, t)
        print("Pruned node_id: " + str(node.id) + " to achieve accuracy: " + str(currentAccuracy*100) + "%")
        # print("Pruned Tree")
        # print_tree(t)
        if currentAccuracy > maxAccuracy:
            maxAccuracy = currentAccuracy
            nodeIdToPrune = node.id
        t = t1
        if maxAccuracy == 1:
            break
    
if nodeIdToPrune != -1:
    t = build_tree(trainDF, header)
    prune_tree(t, [nodeIdToPrune])
    print("\nFinal node Id to prune (for max accuracy): " + str(nodeIdToPrune))
else:
    t = build_tree(trainDF, header)
    print("\nPruning strategy did'nt increased accuracy")

print("\n********************************************************************")
print("*********** Final Tree with accuracy: " + str(maxAccuracy*100) + "%  ************")
print("********************************************************************\n")
print_tree(t)




import graphviz

# Convert the decision tree into a format suitable for Graphviz
def build_graphviz_tree(node, dot=None):
    if dot is None:
        dot = graphviz.Digraph(format='png')
    
    if isinstance(node, Leaf):
        label = f"Predicted: {node.predicted_label}\n{print_leaf(node.predictions)}"
        dot.node(str(node.id), label, shape='box')
    else:
        dot.node(str(node.id), str(node.question))
        
        # True branch
        if isinstance(node.true_branch, Leaf):
            label = f"Predicted: {node.true_branch.predicted_label}\n{print_leaf(node.true_branch.predictions)}"
            dot.node(str(node.true_branch.id), label, shape='box')
            dot.edge(str(node.id), str(node.true_branch.id), label='True')
        else:
            dot.node(str(node.true_branch.id), str(node.true_branch.question))
            dot.edge(str(node.id), str(node.true_branch.id), label='True')
            build_graphviz_tree(node.true_branch, dot)
        
        # False branch
        if isinstance(node.false_branch, Leaf):
            label = f"Predicted: {node.false_branch.predicted_label}\n{print_leaf(node.false_branch.predictions)}"
            dot.node(str(node.false_branch.id), label, shape='box')
            dot.edge(str(node.id), str(node.false_branch.id), label='False')
        else:
            dot.node(str(node.false_branch.id), str(node.false_branch.question))
            dot.edge(str(node.id), str(node.false_branch.id), label='False')
            build_graphviz_tree(node.false_branch, dot)
    
    return dot

# Build the Graphviz tree using the Decision Node structure
graphviz_tree = build_graphviz_tree(t)

# Save the Graphviz tree as an image
graphviz_tree.render('new1', cleanup=True)

print("Decision tree visualization saved as 'new1.png'")
# Out:
# Leaf nodes ****************
# id = 14 depth =3
# id = 13 depth =3
# id = 54 depth =5
# id = 53 depth =5
# id = 52 depth =5
# id = 210 depth =7
# id = 842 depth =9
# id = 841 depth =9
# id = 419 depth =8
# id = 103 depth =6
# id = 24 depth =4
# id = 98 depth =6
# id = 196 depth =7
# id = 392 depth =8
# id = 391 depth =8
# id = 782 depth =9
# id = 781 depth =9
# id = 389 depth =8
# id = 193 depth =7
# id = 95 depth =6
# id = 94 depth =6
# id = 188 depth =7
# id = 754 depth =9
# id = 753 depth =9
# id = 752 depth =9
# id = 1504 depth =10
# id = 3008 depth =11
# id = 3007 depth =11
# id = 186 depth =7
# id = 1494 depth =10
# id = 1493 depth =10
# id = 745 depth =9
# id = 1490 depth =10
# id = 2980 depth =11
# id = 2979 depth =11
# id = 2978 depth =11
# id = 2977 depth =11
# id = 2976 depth =11
# id = 2975 depth =11
# id = 91 depth =6
# id = 366 depth =8
# id = 732 depth =9
# id = 1464 depth =10
# id = 2928 depth =11
# id = 2927 depth =11
# id = 181 depth =7
# id = 89 depth =6
# id = 43 depth =5
# id = 350 depth =8
# id = 1402 depth =10
# id = 2804 depth =11
# id = 2803 depth =11
# id = 699 depth =9
# id = 173 depth =7
# id = 694 depth =9
# id = 693 depth =9
# id = 345 depth =8
# id = 171 depth =7
# id = 84 depth =6
# id = 168 depth =7
# id = 167 depth =7
# id = 334 depth =8
# id = 1338 depth =10
# id = 2676 depth =11
# id = 2675 depth =11
# id = 667 depth =9
# id = 666 depth =9
# id = 665 depth =9
# id = 664 depth =9
# id = 1328 depth =10
# id = 1327 depth =10
# id = 330 depth =8
# id = 660 depth =9
# id = 659 depth =9
# id = 163 depth =7
# id = 80 depth =6
# id = 79 depth =6
# id = 18 depth =4
# id = 74 depth =6
# id = 298 depth =8
# id = 297 depth =8
# id = 147 depth =7
# id = 35 depth =5
# id = 7 depth =3
#
# Non-leaf nodes ****************
# id = 0 depth =0
# id = 2 depth =1
# id = 6 depth =2
# id = 5 depth =2
# id = 12 depth =3
# id = 26 depth =4
# id = 25 depth =4
# id = 51 depth =5
# id = 104 depth =6
# id = 209 depth =7
# id = 420 depth =8
# id = 11 depth =3
# id = 23 depth =4
# id = 48 depth =5
# id = 97 depth =6
# id = 195 depth =7
# id = 47 depth =5
# id = 96 depth =6
# id = 194 depth =7
# id = 390 depth =8
# id = 1 depth =1
# id = 4 depth =2
# id = 10 depth =3
# id = 22 depth =4
# id = 46 depth =5
# id = 93 depth =6
# id = 187 depth =7
# id = 376 depth =8
# id = 375 depth =8
# id = 751 depth =9
# id = 1503 depth =10
# id = 45 depth =5
# id = 92 depth =6
# id = 185 depth =7
# id = 372 depth =8
# id = 746 depth =9
# id = 371 depth =8
# id = 744 depth =9
# id = 1489 depth =10
# id = 743 depth =9
# id = 1488 depth =10
# id = 1487 depth =10
# id = 21 depth =4
# id = 44 depth =5
# id = 90 depth =6
# id = 182 depth =7
# id = 365 depth =8
# id = 731 depth =9
# id = 1463 depth =10
# id = 9 depth =3
# id = 20 depth =4
# id = 42 depth =5
# id = 86 depth =6
# id = 174 depth =7
# id = 349 depth =8
# id = 700 depth =9
# id = 1401 depth =10
# id = 85 depth =6
# id = 172 depth =7
# id = 346 depth =8
# id = 41 depth =5
# id = 83 depth =6
# id = 19 depth =4
# id = 40 depth =5
# id = 82 depth =6
# id = 166 depth =7
# id = 333 depth =8
# id = 668 depth =9
# id = 1337 depth =10
# id = 165 depth =7
# id = 332 depth =8
# id = 331 depth =8
# id = 663 depth =9
# id = 81 depth =6
# id = 164 depth =7
# id = 329 depth =8
# id = 39 depth =5
# id = 3 depth =2
# id = 8 depth =3
# id = 17 depth =4
# id = 36 depth =5
# id = 73 depth =6
# id = 148 depth =7
#
# Tree before pruning with accuracy: 69.0
#
# Is Glucose >= 155.0? id: 0 depth: 0
# --> True:
#   Is Age >= 63.0? id: 2 depth: 1
#   --> True:
#     Is BMI >= 35.5? id: 6 depth: 2
#     --> True:
#       Leaf id: 14 Predictions: {1.0: 1} Label Class: 1.0
#     --> False:
#       Leaf id: 13 Predictions: {0.0: 4} Label Class: 0.0
#   --> False:
#     Is DiabetesPedigreeFunction >= 0.328? id: 5 depth: 2
#     --> True:
#       Is Insulin >= 545.0? id: 12 depth: 3
#       --> True:
#         Is BloodPressure >= 70.0? id: 26 depth: 4
#         --> True:
#           Leaf id: 54 Predictions: {0.0: 3} Label Class: 0.0
#         --> False:
#           Leaf id: 53 Predictions: {1.0: 2} Label Class: 1.0
#       --> False:
#         Is BloodPressure >= 94.0? id: 25 depth: 4
#         --> True:
#           Leaf id: 52 Predictions: {0.0: 1} Label Class: 0.0
#         --> False:
#           Is Insulin >= 265.0? id: 51 depth: 5
#           --> True:
#             Is Pregnancies >= 3.0? id: 104 depth: 6
#             --> True:
#               Leaf id: 210 Predictions: {1.0: 8} Label Class: 1.0
#             --> False:
#               Is Age >= 24.0? id: 209 depth: 7
#               --> True:
#                 Is DiabetesPedigreeFunction >= 0.655? id: 420 depth: 8
#                 --> True:
#                   Leaf id: 842 Predictions: {0.0: 2} Label Class: 0.0
#                 --> False:
#                   Leaf id: 841 Predictions: {1.0: 1} Label Class: 1.0
#               --> False:
#                 Leaf id: 419 Predictions: {1.0: 2} Label Class: 1.0
#           --> False:
#             Leaf id: 103 Predictions: {1.0: 41} Label Class: 1.0
#     --> False:
#       Is Glucose >= 181.0? id: 11 depth: 3
#       --> True:
#         Leaf id: 24 Predictions: {1.0: 9} Label Class: 1.0
#       --> False:
#         Is Age >= 38.0? id: 23 depth: 4
#         --> True:
#           Is Age >= 54.0? id: 48 depth: 5
#           --> True:
#             Leaf id: 98 Predictions: {0.0: 2} Label Class: 0.0
#           --> False:
#             Is Age >= 41.0? id: 97 depth: 6
#             --> True:
#               Leaf id: 196 Predictions: {1.0: 10} Label Class: 1.0
#             --> False:
#               Is Age >= 40.0? id: 195 depth: 7
#               --> True:
#                 Leaf id: 392 Predictions: {0.0: 1} Label Class: 0.0
#               --> False:
#                 Leaf id: 391 Predictions: {1.0: 2} Label Class: 1.0
#         --> False:
#           Is BMI >= 31.6? id: 47 depth: 5
#           --> True:
#             Is Age >= 26.0? id: 96 depth: 6
#             --> True:
#               Is DiabetesPedigreeFunction >= 0.268? id: 194 depth: 7
#               --> True:
#                 Is Age >= 28.0? id: 390 depth: 8
#                 --> True:
#                   Leaf id: 782 Predictions: {1.0: 2} Label Class: 1.0
#                 --> False:
#                   Leaf id: 781 Predictions: {0.0: 1} Label Class: 0.0
#               --> False:
#                 Leaf id: 389 Predictions: {0.0: 3} Label Class: 0.0
#             --> False:
#               Leaf id: 193 Predictions: {1.0: 2} Label Class: 1.0
#           --> False:
#             Leaf id: 95 Predictions: {0.0: 3} Label Class: 0.0
# --> False:
#   Is BMI >= 26.4? id: 1 depth: 1
#   --> True:
#     Is Age >= 29.0? id: 4 depth: 2
#     --> True:
#       Is Glucose >= 101.0? id: 10 depth: 3
#       --> True:
#         Is DiabetesPedigreeFunction >= 0.516? id: 22 depth: 4
#         --> True:
#           Is BMI >= 42.9? id: 46 depth: 5
#           --> True:
#             Leaf id: 94 Predictions: {1.0: 9} Label Class: 1.0
#           --> False:
#             Is DiabetesPedigreeFunction >= 1.4? id: 93 depth: 6
#             --> True:
#               Leaf id: 188 Predictions: {0.0: 3} Label Class: 0.0
#             --> False:
#               Is Pregnancies >= 8.0? id: 187 depth: 7
#               --> True:
#                 Is Glucose >= 153.0? id: 376 depth: 8
#                 --> True:
#                   Leaf id: 754 Predictions: {0.0: 1} Label Class: 0.0
#                 --> False:
#                   Leaf id: 753 Predictions: {1.0: 13} Label Class: 1.0
#               --> False:
#                 Is BMI >= 38.9? id: 375 depth: 8
#                 --> True:
#                   Leaf id: 752 Predictions: {0.0: 3} Label Class: 0.0
#                 --> False:
#                   Is DiabetesPedigreeFunction >= 0.875? id: 751 depth: 9
#                   --> True:
#                     Leaf id: 1504 Predictions: {1.0: 7} Label Class: 1.0
#                   --> False:
#                     Is Insulin >= 193.0? id: 1503 depth: 10
#                     --> True:
#                       Leaf id: 3008 Predictions: {0.0: 3} Label Class: 0.0
#                     --> False:
#                       Leaf id: 3007 Predictions: {0.0: 5, 1.0: 9} Label Class: 1.0
#         --> False:
#           Is DiabetesPedigreeFunction >= 0.128? id: 45 depth: 5
#           --> True:
#             Is BMI >= 46.1? id: 92 depth: 6
#             --> True:
#               Leaf id: 186 Predictions: {1.0: 4} Label Class: 1.0
#             --> False:
#               Is BloodPressure >= 85.0? id: 185 depth: 7
#               --> True:
#                 Is Insulin >= 140.0? id: 372 depth: 8
#                 --> True:
#                   Is Age >= 43.0? id: 746 depth: 9
#                   --> True:
#                     Leaf id: 1494 Predictions: {1.0: 3} Label Class: 1.0
#                   --> False:
#                     Leaf id: 1493 Predictions: {0.0: 1} Label Class: 0.0
#                 --> False:
#                   Leaf id: 745 Predictions: {0.0: 12} Label Class: 0.0
#               --> False:
#                 Is BMI >= 33.1? id: 371 depth: 8
#                 --> True:
#                   Is DiabetesPedigreeFunction >= 0.374? id: 744 depth: 9
#                   --> True:
#                     Leaf id: 1490 Predictions: {0.0: 5} Label Class: 0.0
#                   --> False:
#                     Is Insulin >= 194.0? id: 1489 depth: 10
#                     --> True:
#                       Leaf id: 2980 Predictions: {0.0: 3} Label Class: 0.0
#                     --> False:
#                       Leaf id: 2979 Predictions: {0.0: 11, 1.0: 11} Label Class: 0.0
#                 --> False:
#                   Is Age >= 59.0? id: 743 depth: 9
#                   --> True:
#                     Is Age >= 70.0? id: 1488 depth: 10
#                     --> True:
#                       Leaf id: 2978 Predictions: {1.0: 1} Label Class: 1.0
#                     --> False:
#                       Leaf id: 2977 Predictions: {0.0: 4} Label Class: 0.0
#                   --> False:
#                     Is BMI >= 32.0? id: 1487 depth: 10
#                     --> True:
#                       Leaf id: 2976 Predictions: {1.0: 6} Label Class: 1.0
#                     --> False:
#                       Leaf id: 2975 Predictions: {1.0: 19, 0.0: 12} Label Class: 1.0
#           --> False:
#             Leaf id: 91 Predictions: {0.0: 5} Label Class: 0.0
#       --> False:
#         Is Glucose >= 61.0? id: 21 depth: 4
#         --> True:
#           Is Glucose >= 84.0? id: 44 depth: 5
#           --> True:
#             Is Age >= 31.0? id: 90 depth: 6
#             --> True:
#               Is DiabetesPedigreeFunction >= 1.224? id: 182 depth: 7
#               --> True:
#                 Leaf id: 366 Predictions: {1.0: 1} Label Class: 1.0
#               --> False:
#                 Is Insulin >= 215.0? id: 365 depth: 8
#                 --> True:
#                   Leaf id: 732 Predictions: {1.0: 1} Label Class: 1.0
#                 --> False:
#                   Is SkinThickness >= 33.0? id: 731 depth: 9
#                   --> True:
#                     Leaf id: 1464 Predictions: {0.0: 6} Label Class: 0.0
#                   --> False:
#                     Is SkinThickness >= 31.0? id: 1463 depth: 10
#                     --> True:
#                       Leaf id: 2928 Predictions: {1.0: 3, 0.0: 1} Label Class: 1.0
#                     --> False:
#                       Leaf id: 2927 Predictions: {1.0: 4, 0.0: 15} Label Class: 0.0
#             --> False:
#               Leaf id: 181 Predictions: {0.0: 5} Label Class: 0.0
#           --> False:
#             Leaf id: 89 Predictions: {0.0: 13} Label Class: 0.0
#         --> False:
#           Leaf id: 43 Predictions: {1.0: 2} Label Class: 1.0
#     --> False:
#       Is Glucose >= 128.0? id: 9 depth: 3
#       --> True:
#         Is BloodPressure >= 62.0? id: 20 depth: 4
#         --> True:
#           Is Pregnancies >= 1.0? id: 42 depth: 5
#           --> True:
#             Is Age >= 25.0? id: 86 depth: 6
#             --> True:
#               Is DiabetesPedigreeFunction >= 0.571? id: 174 depth: 7
#               --> True:
#                 Leaf id: 350 Predictions: {0.0: 4} Label Class: 0.0
#               --> False:
#                 Is SkinThickness >= 25.0? id: 349 depth: 8
#                 --> True:
#                   Is BMI >= 31.6? id: 700 depth: 9
#                   --> True:
#                     Leaf id: 1402 Predictions: {1.0: 3} Label Class: 1.0
#                   --> False:
#                     Is Age >= 28.0? id: 1401 depth: 10
#                     --> True:
#                       Leaf id: 2804 Predictions: {1.0: 1} Label Class: 1.0
#                     --> False:
#                       Leaf id: 2803 Predictions: {0.0: 2} Label Class: 0.0
#                 --> False:
#                   Leaf id: 699 Predictions: {0.0: 4} Label Class: 0.0
#             --> False:
#               Leaf id: 173 Predictions: {0.0: 8} Label Class: 0.0
#           --> False:
#             Is BloodPressure >= 70.0? id: 85 depth: 6
#             --> True:
#               Is Age >= 22.0? id: 172 depth: 7
#               --> True:
#                 Is Age >= 28.0? id: 346 depth: 8
#                 --> True:
#                   Leaf id: 694 Predictions: {1.0: 1} Label Class: 1.0
#                 --> False:
#                   Leaf id: 693 Predictions: {0.0: 5} Label Class: 0.0
#               --> False:
#                 Leaf id: 345 Predictions: {1.0: 1} Label Class: 1.0
#             --> False:
#               Leaf id: 171 Predictions: {1.0: 4} Label Class: 1.0
#         --> False:
#           Is Age >= 24.0? id: 41 depth: 5
#           --> True:
#             Leaf id: 84 Predictions: {1.0: 5} Label Class: 1.0
#           --> False:
#             Is Age >= 22.0? id: 83 depth: 6
#             --> True:
#               Leaf id: 168 Predictions: {0.0: 1} Label Class: 0.0
#             --> False:
#               Leaf id: 167 Predictions: {1.0: 1} Label Class: 1.0
#       --> False:
#         Is BMI >= 31.0? id: 19 depth: 4
#         --> True:
#           Is BloodPressure >= 54.0? id: 40 depth: 5
#           --> True:
#             Is DiabetesPedigreeFunction >= 0.51? id: 82 depth: 6
#             --> True:
#               Is BMI >= 39.1? id: 166 depth: 7
#               --> True:
#                 Leaf id: 334 Predictions: {0.0: 9} Label Class: 0.0
#               --> False:
#                 Is BMI >= 32.3? id: 333 depth: 8
#                 --> True:
#                   Is SkinThickness >= 41.0? id: 668 depth: 9
#                   --> True:
#                     Leaf id: 1338 Predictions: {1.0: 2} Label Class: 1.0
#                   --> False:
#                     Is BMI >= 34.4? id: 1337 depth: 10
#                     --> True:
#                       Leaf id: 2676 Predictions: {0.0: 7, 1.0: 2} Label Class: 0.0
#                     --> False:
#                       Leaf id: 2675 Predictions: {1.0: 5, 0.0: 3} Label Class: 1.0
#                 --> False:
#                   Leaf id: 667 Predictions: {0.0: 4} Label Class: 0.0
#             --> False:
#               Is BloodPressure >= 85.0? id: 165 depth: 7
#               --> True:
#                 Is Age >= 25.0? id: 332 depth: 8
#                 --> True:
#                   Leaf id: 666 Predictions: {0.0: 3} Label Class: 0.0
#                 --> False:
#                   Leaf id: 665 Predictions: {1.0: 2} Label Class: 1.0
#               --> False:
#                 Is SkinThickness >= 17.0? id: 331 depth: 8
#                 --> True:
#                   Leaf id: 664 Predictions: {0.0: 46} Label Class: 0.0
#                 --> False:
#                   Is Age >= 24.0? id: 663 depth: 9
#                   --> True:
#                     Leaf id: 1328 Predictions: {0.0: 3} Label Class: 0.0
#                   --> False:
#                     Leaf id: 1327 Predictions: {1.0: 1} Label Class: 1.0
#           --> False:
#             Is BMI >= 34.4? id: 81 depth: 6
#             --> True:
#               Is Insulin >= 158.0? id: 164 depth: 7
#               --> True:
#                 Leaf id: 330 Predictions: {0.0: 3} Label Class: 0.0
#               --> False:
#                 Is BMI >= 36.0? id: 329 depth: 8
#                 --> True:
#                   Leaf id: 660 Predictions: {1.0: 2} Label Class: 1.0
#                 --> False:
#                   Leaf id: 659 Predictions: {0.0: 1} Label Class: 0.0
#             --> False:
#               Leaf id: 163 Predictions: {1.0: 3} Label Class: 1.0
#         --> False:
#           Is Pregnancies >= 8.0? id: 39 depth: 5
#           --> True:
#             Leaf id: 80 Predictions: {1.0: 1} Label Class: 1.0
#           --> False:
#             Leaf id: 79 Predictions: {0.0: 51} Label Class: 0.0
#   --> False:
#     Is Glucose >= 107.0? id: 3 depth: 2
#     --> True:
#       Is Insulin >= 50.0? id: 8 depth: 3
#       --> True:
#         Leaf id: 18 Predictions: {0.0: 26} Label Class: 0.0
#       --> False:
#         Is BMI >= 21.0? id: 17 depth: 4
#         --> True:
#           Is Insulin >= 48.0? id: 36 depth: 5
#           --> True:
#             Leaf id: 74 Predictions: {1.0: 1} Label Class: 1.0
#           --> False:
#             Is Glucose >= 134.0? id: 73 depth: 6
#             --> True:
#               Is DiabetesPedigreeFunction >= 0.277? id: 148 depth: 7
#               --> True:
#                 Leaf id: 298 Predictions: {1.0: 2} Label Class: 1.0
#               --> False:
#                 Leaf id: 297 Predictions: {0.0: 4} Label Class: 0.0
#             --> False:
#               Leaf id: 147 Predictions: {0.0: 20} Label Class: 0.0
#         --> False:
#           Leaf id: 35 Predictions: {1.0: 2} Label Class: 1.0
#     --> False:
#       Leaf id: 7 Predictions: {0.0: 70} Label Class: 0.0
# Pruned node_id: 2 to achieve accuracy: 71.0%
# Pruned node_id: 6 to achieve accuracy: 69.0%
# Pruned node_id: 5 to achieve accuracy: 71.0%
# Pruned node_id: 12 to achieve accuracy: 71.0%
# Pruned node_id: 26 to achieve accuracy: 71.0%
# Pruned node_id: 25 to achieve accuracy: 71.0%
# Pruned node_id: 51 to achieve accuracy: 71.0%
# Pruned node_id: 104 to achieve accuracy: 71.0%
# Pruned node_id: 209 to achieve accuracy: 71.0%
# Pruned node_id: 420 to achieve accuracy: 71.0%
# Pruned node_id: 11 to achieve accuracy: 71.0%
# Pruned node_id: 23 to achieve accuracy: 71.0%
# Pruned node_id: 48 to achieve accuracy: 71.0%
# Pruned node_id: 97 to achieve accuracy: 71.0%
# Pruned node_id: 195 to achieve accuracy: 71.0%
# Pruned node_id: 47 to achieve accuracy: 71.0%
# Pruned node_id: 96 to achieve accuracy: 71.0%
# Pruned node_id: 194 to achieve accuracy: 71.0%
# Pruned node_id: 390 to achieve accuracy: 71.0%
# Pruned node_id: 1 to achieve accuracy: 72.0%
# Pruned node_id: 4 to achieve accuracy: 72.0%
# Pruned node_id: 10 to achieve accuracy: 72.0%
# Pruned node_id: 22 to achieve accuracy: 72.0%
# Pruned node_id: 46 to achieve accuracy: 72.0%
# Pruned node_id: 93 to achieve accuracy: 72.0%
# Pruned node_id: 187 to achieve accuracy: 72.0%
# Pruned node_id: 376 to achieve accuracy: 72.0%
# Pruned node_id: 375 to achieve accuracy: 72.0%
# Pruned node_id: 751 to achieve accuracy: 72.0%
# Pruned node_id: 1503 to achieve accuracy: 72.0%
# Pruned node_id: 45 to achieve accuracy: 72.0%
# Pruned node_id: 92 to achieve accuracy: 72.0%
# Pruned node_id: 185 to achieve accuracy: 72.0%
# Pruned node_id: 372 to achieve accuracy: 72.0%
# Pruned node_id: 746 to achieve accuracy: 72.0%
# Pruned node_id: 371 to achieve accuracy: 72.0%
# Pruned node_id: 744 to achieve accuracy: 72.0%
# Pruned node_id: 1489 to achieve accuracy: 72.0%
# Pruned node_id: 743 to achieve accuracy: 72.0%
# Pruned node_id: 1488 to achieve accuracy: 72.0%
# Pruned node_id: 1487 to achieve accuracy: 72.0%
# Pruned node_id: 21 to achieve accuracy: 72.0%
# Pruned node_id: 44 to achieve accuracy: 72.0%
# Pruned node_id: 90 to achieve accuracy: 72.0%
# Pruned node_id: 182 to achieve accuracy: 72.0%
# Pruned node_id: 365 to achieve accuracy: 72.0%
# Pruned node_id: 731 to achieve accuracy: 72.0%
# Pruned node_id: 1463 to achieve accuracy: 72.0%
# Pruned node_id: 9 to achieve accuracy: 72.0%
# Pruned node_id: 20 to achieve accuracy: 72.0%
# Pruned node_id: 42 to achieve accuracy: 72.0%
# Pruned node_id: 86 to achieve accuracy: 72.0%
# Pruned node_id: 174 to achieve accuracy: 72.0%
# Pruned node_id: 349 to achieve accuracy: 72.0%
# Pruned node_id: 700 to achieve accuracy: 72.0%
# Pruned node_id: 1401 to achieve accuracy: 72.0%
# Pruned node_id: 85 to achieve accuracy: 72.0%
# Pruned node_id: 172 to achieve accuracy: 72.0%
# Pruned node_id: 346 to achieve accuracy: 72.0%
# Pruned node_id: 41 to achieve accuracy: 72.0%
# Pruned node_id: 83 to achieve accuracy: 72.0%
# Pruned node_id: 19 to achieve accuracy: 72.0%
# Pruned node_id: 40 to achieve accuracy: 72.0%
# Pruned node_id: 82 to achieve accuracy: 72.0%
# Pruned node_id: 166 to achieve accuracy: 72.0%
# Pruned node_id: 333 to achieve accuracy: 72.0%
# Pruned node_id: 668 to achieve accuracy: 72.0%
# Pruned node_id: 1337 to achieve accuracy: 72.0%
# Pruned node_id: 165 to achieve accuracy: 72.0%
# Pruned node_id: 332 to achieve accuracy: 72.0%
# Pruned node_id: 331 to achieve accuracy: 72.0%
# Pruned node_id: 663 to achieve accuracy: 72.0%
# Pruned node_id: 81 to achieve accuracy: 72.0%
# Pruned node_id: 164 to achieve accuracy: 72.0%
# Pruned node_id: 329 to achieve accuracy: 72.0%
# Pruned node_id: 39 to achieve accuracy: 72.0%
# Pruned node_id: 3 to achieve accuracy: 72.0%
# Pruned node_id: 8 to achieve accuracy: 72.0%
# Pruned node_id: 17 to achieve accuracy: 72.0%
# Pruned node_id: 36 to achieve accuracy: 72.0%
# Pruned node_id: 73 to achieve accuracy: 72.0%
# Pruned node_id: 148 to achieve accuracy: 72.0%
# Final node Id to prune (for max accuracy): 1
#
# ********************************************************************
# *********** Final Tree with accuracy: 72.0%  ************
# ********************************************************************
#
# Is Glucose >= 155.0? id: 0 depth: 0
# --> True:
#   Is Age >= 63.0? id: 2 depth: 1
#   --> True:
#     Is BMI >= 35.5? id: 6 depth: 2
#     --> True:
#       Leaf id: 14 Predictions: {1.0: 1} Label Class: 1.0
#     --> False:
#       Leaf id: 13 Predictions: {0.0: 4} Label Class: 0.0
#   --> False:
#     Is DiabetesPedigreeFunction >= 0.328? id: 5 depth: 2
#     --> True:
#       Is Insulin >= 545.0? id: 12 depth: 3
#       --> True:
#         Is BloodPressure >= 70.0? id: 26 depth: 4
#         --> True:
#           Leaf id: 54 Predictions: {0.0: 3} Label Class: 0.0
#         --> False:
#           Leaf id: 53 Predictions: {1.0: 2} Label Class: 1.0
#       --> False:
#         Is BloodPressure >= 94.0? id: 25 depth: 4
#         --> True:
#           Leaf id: 52 Predictions: {0.0: 1} Label Class: 0.0
#         --> False:
#           Is Insulin >= 265.0? id: 51 depth: 5
#           --> True:
#             Is Pregnancies >= 3.0? id: 104 depth: 6
#             --> True:
#               Leaf id: 210 Predictions: {1.0: 8} Label Class: 1.0
#             --> False:
#               Is Age >= 24.0? id: 209 depth: 7
#               --> True:
#                 Is DiabetesPedigreeFunction >= 0.655? id: 420 depth: 8
#                 --> True:
#                   Leaf id: 842 Predictions: {0.0: 2} Label Class: 0.0
#                 --> False:
#                   Leaf id: 841 Predictions: {1.0: 1} Label Class: 1.0
#               --> False:
#                 Leaf id: 419 Predictions: {1.0: 2} Label Class: 1.0
#           --> False:
#             Leaf id: 103 Predictions: {1.0: 41} Label Class: 1.0
#     --> False:
#       Is Glucose >= 181.0? id: 11 depth: 3
#       --> True:
#         Leaf id: 24 Predictions: {1.0: 9} Label Class: 1.0
#       --> False:
#         Is Age >= 38.0? id: 23 depth: 4
#         --> True:
#           Is Age >= 54.0? id: 48 depth: 5
#           --> True:
#             Leaf id: 98 Predictions: {0.0: 2} Label Class: 0.0
#           --> False:
#             Is Age >= 41.0? id: 97 depth: 6
#             --> True:
#               Leaf id: 196 Predictions: {1.0: 10} Label Class: 1.0
#             --> False:
#               Is Age >= 40.0? id: 195 depth: 7
#               --> True:
#                 Leaf id: 392 Predictions: {0.0: 1} Label Class: 0.0
#               --> False:
#                 Leaf id: 391 Predictions: {1.0: 2} Label Class: 1.0
#         --> False:
#           Is BMI >= 31.6? id: 47 depth: 5
#           --> True:
#             Is Age >= 26.0? id: 96 depth: 6
#             --> True:
#               Is DiabetesPedigreeFunction >= 0.268? id: 194 depth: 7
#               --> True:
#                 Is Age >= 28.0? id: 390 depth: 8
#                 --> True:
#                   Leaf id: 782 Predictions: {1.0: 2} Label Class: 1.0
#                 --> False:
#                   Leaf id: 781 Predictions: {0.0: 1} Label Class: 0.0
#               --> False:
#                 Leaf id: 389 Predictions: {0.0: 3} Label Class: 0.0
#             --> False:
#               Leaf id: 193 Predictions: {1.0: 2} Label Class: 1.0
#           --> False:
#             Leaf id: 95 Predictions: {0.0: 3} Label Class: 0.0
# --> False:
#   Leaf id: 1 Predictions: {0.0: 382, 1.0: 132} Label Class: 0.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23496\37766759.py in <module>
#     439
#     440
# --> 441 import graphviz
#     442
#     443 # Convert the decision tree into a format suitable for Graphviz
#
# ModuleNotFoundError: No module named 'graphviz'
